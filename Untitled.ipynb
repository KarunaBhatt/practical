# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=[20,25,35,55]

plt.plot(x,y)
plt.title("Line chart")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
y = [10, 20, 15, 25, 30]

plt.bar(x, y)

plt.xlabel('Days of the Week')
plt.ylabel('Values')
plt.title('Bar Chart Example')

   plt.show()

# %%
import matplotlib.pyplot as plt

x=['Monday','Tuesday','Wednsday','Thursday','Friday']
y=[10,20,15,25,30]

plt.xlabel('Days of the week')
plt.ylabel('values')
plt.title('Bar chart')
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data: Random data to simulate ages
data = [23, 45, 56, 67, 45, 34, 23, 56, 78, 45, 23, 56, 45, 34, 23, 23, 45, 67, 45, 23]

# Create the histogram
plt.hist(data, bins=5, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data for the pie chart (e.g., market share of different companies)
labels = ['Company A', 'Company B', 'Company C', 'Company D']
sizes = [30, 25, 20, 25]  # These are the market share percentages

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Add a title
plt.title('Market Share Distribution')

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

# Create the scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Scatter Plot')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,4,9,16,25]
y1=[25,20,15,10,5]

plt.plot(x,y1,label='Line 1',color='blue',marker='o')

plt.plot(x,y2,label='Line 2',color='red',marker='x')

plt.xlabel(X-axis)
plt.ylabel(y-axis)
plt.title('multiple line chart')

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 9
#       5 y1=[25,20,15,10,5]
#       7 plt.plot(x,y1,label='Line 1',color='blue',marker='o')
# ----> 9 plt.plot(x,y2,label='Line 2',color='red',marker='x')
#      11 plt.xlabel(X-axis)
#      12 plt.ylabel(y-axis)
#
# NameError: name 'y2' is not defined

# %%
import weakref

class classroom:
    _students = []
    def __init__(self,name,std,rollno):
        self.name = name
        self.std = std
        self.rollno = rollno
        self.__class__._students.append(self)
    
    @classmethod    
    def display(cls):
        for i in cls._students:
            print(i.rollno)  
            
    @classmethod
    def delete(cls,std):
        cls._students.remove(std)
        print(std.name+" is removed from classroom")
        del std
    
    @classmethod
    def search(cls,rno):
        for i in cls._students:
            if i.rollno == rno:
                print("Roll no"+ rno + "is" +i.name)
                break
        

std1 = classroom('Abby',8,1)
std2 = classroom('pazu',8,2)

classroom.display()   

classroom.delete(std1)

classroom.display()

classroom.search(2)
# Out:
# 1
# 2
# Abby is removed from classroom
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 39
#      35 classroom.delete(std1)
#      37 classroom.display()
# ---> 39 classroom.search(2)
#
# Cell In[71], line 26, in classroom.search(cls, rno)
#      24 for i in cls._students:
#      25     if i.rollno == rno:
# ---> 26         print("Roll no"+ rno + "is" +i.name)
#      27         break
#
# TypeError: can only concatenate str (not "int") to str

# %%
import weakref

class classroom:
    _students = []
    def __init__ (self,name,std,rollno):
        self.name = name
        self.std = std
        self.rollno = rollno
        self.__class__._students.append(self)
        
    @classmethod
    def display(cls):
        for i in cls._students:
            print(i.rollno)
            
    @classmethod
    def delete(cls,std):
        cls._students.remove(std)
        print(std.name+" is removed from classroom")
        del std   
        
    @classmethod
    def search(cls,rno):
        for i in cls._students:
            if i.rollno ==rno:
                print("Roll no {} is" {}".format(rno,i.name))
                break
            
std1 = classroom('Abby',8,1)
std2 = classroom('pazu',8,2)

classroom.display()
              
classroom.delete(std1)

classroom.display()

classroom.search(2)
# Out:
#   Cell In[92], line 26
#     print("Roll no {} is" {}".format(rno,i.name))
#                             ^
# SyntaxError: unterminated string literal (detected at line 26)

# %%
class classroom:
    __students =[]
    def __init__(self,name,std,rollno):
        self.name = name
        self.std = std
        self.rollno = rollno
        self.__class__._students.append(self)
        
        def display(cls):
            for i in cls._students:
                print(i.name)
                
std1 = classroom('Abby',8,1)
std2 = classroom('pazu',8,2)

classroom.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 13
#      10             for i in cls._students:
#      11                 print(i.name)
# ---> 13 std1 = classroom('Abby',8,1)
#      14 std2 = classroom('pazu',8,2)
#      16 classroom.display()
#
# Cell In[91], line 7, in classroom.__init__(self, name, std, rollno)
#       5 self.std = std
#       6 self.rollno = rollno
# ----> 7 self.__class__._students.append(self)
#       9 def display(cls):
#      10     for i in cls._students:
#
# AttributeError: type object 'classroom' has no attribute '_students'
